# %%
import pickle
import numpy as np

pkl_file = open('params_epoch_10', 'rb')
params = pickle.load(pkl_file)

# %%
params[0]
# Out:
# array([[[[-0.14231701,  0.09048937, -0.01753061,  0.11271215, -0.16411899,
#           -0.13524044, -0.17971183],
#          [-0.08037773,  0.07875997,  0.15351316, -0.02801483,  0.00309414,
#           -0.10949489, -0.07191249],
#          [-0.08219822, -0.00527706,  0.16719595,  0.08470207,  0.21508414,
#            0.02443749, -0.22873078],
#          [-0.02937089,  0.16587891,  0.03856071,  0.14286427,  0.1632347 ,
#            0.14252684, -0.05081138],
#          [ 0.12862098,  0.19023065,  0.11082391,  0.11186044,  0.15245944,
#           -0.0201923 , -0.17791063],
#          [-0.17702261,  0.0281436 ,  0.00274088,  0.03125722,  0.15052269,
#           -0.1804733 , -0.03572487],
#          [-0.17821807, -0.12907755,  0.16599309,  0.11069912, -0.13597348,
#           -0.18226106, -0.05821263]]],
#
#
#        [[[-0.02810718,  0.19569448, -0.06478914, -0.01805051,  0.05320404,
#            0.0050831 , -0.08451571],
# ...
